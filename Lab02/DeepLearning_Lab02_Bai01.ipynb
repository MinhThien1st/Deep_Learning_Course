# %%
from tensorflow.keras.datasets import cifar10

(X_train,y_train),(X_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
X_train = X_train.reshape(50000,3072)

X_test = X_test.reshape(10000,3072)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train,10)

y_test = to_categorical(y_test,10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(
    512,
    activation='relu',
    input_dim=3072
))

model.add(Dense(
    256,
    activation='relu'
))

model.add(Dense(
    10,
    activation='softmax'
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.3132 - loss: 1.9342 - val_accuracy: 0.3596 - val_loss: 1.7800
# Epoch 2/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.3911 - loss: 1.6975 - val_accuracy: 0.3978 - val_loss: 1.6672
# Epoch 3/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4230 - loss: 1.6145 - val_accuracy: 0.4344 - val_loss: 1.5980
# Epoch 4/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4510 - loss: 1.5417 - val_accuracy: 0.4526 - val_loss: 1.5351
# Epoch 5/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.4653 - loss: 1.5023 - val_accuracy: 0.4630 - val_loss: 1.5073
# Epoch 6/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.4796 - loss: 1.4630 - val_accuracy: 0.4776 - val_loss: 1.4689
# Epoch 7/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.4894 - loss: 1.4329 - val_accuracy: 0.4664 - val_loss: 1.4846
# Epoch 8/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.5015 - loss: 1.4055 - val_accuracy: 0.4752 - val_loss: 1.4805
# Epoch 9/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.5069 - loss: 1.3875 - val_accuracy: 0.4912 - val_loss: 1.4525
# Epoch 10/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.5143 - loss: 1.3525 - val_accuracy: 0.4840 - val_loss: 1.4758

# %%
loss,accuracy = model.evaluate(
    X_test,
    y_test
)

print(accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4862 - loss: 1.4696
# 0.4862000048160553
